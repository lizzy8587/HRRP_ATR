# %%
import scipy.io as scio
import matplotlib.pyplot as plt
import numpy as np

# %%
# mat_path = r'G:\烟台实验数据已切\results\1111\Device1_PCData_Range_90.00Km_20221111082734941\370007000+货船\370007000data.mat'
mat_path = r'G:\烟台实验数据已切\hrrp标注\146\123456789+训练舰\d1461data.mat'
z = list(scio.loadmat(mat_path).values())[-1]
z = abs(z)

# %%
x,y = np.meshgrid(
    np.linspace(0,z.shape[1]-1,z.shape[1]),
    np.linspace(0,z.shape[0]-1,z.shape[0])
)

plt.contourf(x, y, z)
