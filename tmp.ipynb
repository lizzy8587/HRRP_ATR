# %%
import scipy.io as scio
import matplotlib.pyplot as plt
import numpy as np
from utils.dataprocess import YantaiData

# %%
mat_path = r'G:\烟台实验数据已切\hrrp标注\146\123456789+训练舰\d1461data.mat'
hrrp2d = YantaiData.read_hrrp_mat(mat_path)
YantaiData.plot_hrrp2d(hrrp2d, colorbar=True)

# %%
YantaiData.plot_hrrp1d(hrrp2d[308])
